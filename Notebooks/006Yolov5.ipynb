# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/UpWork/Protein/Yolo/'
# !git clone --depth 1  --branch master https://github.com/ultralytics/yolov5
# %cd /content

# %%
# !pip install -r /content/drive/MyDrive/UpWork/Protein/Yolo/yolov5/requirements.txt

# %%
# !python /content/drive/MyDrive/UpWork/Protein/Yolo/yolov5/train.py \
  --data /content/drive/MyDrive/UpWork/Protein/Yolo/yoloconfig.yaml \
  --hyp /content/drive/MyDrive/UpWork/Protein/Yolo/yolov5/data/hyps/hyp.finetune.yaml \
  --project /content/drive/MyDrive/UpWork/Protein/Yolo/Data/ \
  --name model4 \
  --weights yolov5s.pt \
  --imgsz 512 --batch 4 --epochs 500
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/drive/MyDrive/UpWork/Protein/Yolo/yoloconfig.yaml, hyp=/content/drive/MyDrive/UpWork/Protein/Yolo/yolov5/data/hyps/hyp.finetune.yaml, epochs=500, batch_size=4, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=/content/drive/MyDrive/UpWork/Protein/Yolo/Data/, entity=None, name=model4, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0, patience=30
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2021-8-30 torch 1.9.0+cu102 CUDA:0 (Tesla K80, 11441.1875MB)
#
# ...

# %%
# !python /content/drive/MyDrive/UpWork/Protein/Yolo/yolov5/train.py \
  --data /content/drive/MyDrive/UpWork/Protein/Yolo/yoloconfig.yaml \
  --hyp /content/drive/MyDrive/UpWork/Protein/Yolo/yolov5/data/hyps/hyp.finetune.yaml \
  --project /content/drive/MyDrive/UpWork/Protein/Yolo/Data/ \
  --name model5 \
  --weights /content/drive/MyDrive/UpWork/Protein/Yolo/Data/model4/weights/last.pt \
  --imgsz 512 --batch 4 --epochs 500 --patience 100
# Out:
# train: weights=/content/drive/MyDrive/UpWork/Protein/Yolo/Data/model4/weights/last.pt, cfg=, data=/content/drive/MyDrive/UpWork/Protein/Yolo/yoloconfig.yaml, hyp=/content/drive/MyDrive/UpWork/Protein/Yolo/yolov5/data/hyps/hyp.finetune.yaml, epochs=500, batch_size=4, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=/content/drive/MyDrive/UpWork/Protein/Yolo/Data/, entity=None, name=model5, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0, patience=100
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2021-8-30 torch 1.9.0+cu102 CUDA:0 (Tesla K80, 11441.1875MB)
#
# ...

# %%
# !python /content/drive/MyDrive/UpWork/Protein/Yolo/yolov5/train.py \
  --data /content/drive/MyDrive/UpWork/Protein/Yolo/yoloconfig.yaml \
  --hyp /content/drive/MyDrive/UpWork/Protein/Yolo/yolov5/data/hyps/hyp.finetune.yaml \
  --project /content/drive/MyDrive/UpWork/Protein/Yolo/Data/ \
  --name model5 \
  --weights /content/drive/MyDrive/UpWork/Protein/Yolo/Data/model4/weights/last.pt \
  --imgsz 512 --batch 4 --epochs 500 --patience 100 --resume
# Out:
# train: weights=/content/drive/MyDrive/UpWork/Protein/Yolo/Data/model4/weights/last.pt, cfg=, data=/content/drive/MyDrive/UpWork/Protein/Yolo/yoloconfig.yaml, hyp=/content/drive/MyDrive/UpWork/Protein/Yolo/yolov5/data/hyps/hyp.finetune.yaml, epochs=500, batch_size=4, imgsz=512, rect=False, resume=True, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=/content/drive/MyDrive/UpWork/Protein/Yolo/Data/, entity=None, name=model5, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0, patience=100
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# Resuming training from ./drive/MyDrive/UpWork/Protein/Yolo/Data/model5/weights/last.pt
# YOLOv5 🚀 2021-8-30 torch 1.9.0+cu102 CPU
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
model_name = ['model4', 'model5', 'model6']
base_path = "/content/drive/MyDrive/UpWork/Protein/Yolo/Data/{}/results.csv"
data = []
for model in model_name:
  data_temp = pd.read_csv(base_path.format(model))
  data.append(data_temp)
data = pd.concat(data)
data['epochs'] = range(len(data))

# %%
plt.plot(data['epochs'], data['     metrics/mAP_0.5'])
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Average Precision")
plt.title("Validation - AP")
plt.show()
# Out:
# No handles with labels found to put in legend.
